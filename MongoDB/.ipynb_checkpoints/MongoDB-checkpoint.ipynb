# %%
#! pip install pymongo
from pymongo import MongoClient
#! pip install pprint
from pprint import pprint
#! pip install pandas
import pandas as pd

# %% [markdown]
# #### Creación de la conección a la base de datos

# %%
client = MongoClient('mongodb+srv://admin:admin@cluster0-fms85.mongodb.net/test?retryWrites=true&w=majority')

# %%
db = client.unidadVictimas
# Issue the serverStatus command and print the results
serverStatusResult = db.command("serverStatus")
#pprint(serverStatusResult)

# %% [markdown]
# #### Configuración de las rutas de los archivos a cargar

# %%
accionesBelicas = "Microdatos\casos_acciones_belicas.csv"
danosBienes = "Microdatos\casos_danos_bienes.csv"
casosDesaparicion = "Microdatos\casos_desaparicion.csv"
casosMapMuse = "Microdatos\casos_map_muse.csv"
victimasAcciones = "Microdatos\\victimas_acciones_belicas.csv"
victimasDanos = "Microdatos\\victimas_danos_bienes.csv"
victimasDesaparicion = "Microdatos\\victimas_desaparicion.csv"
victimasMapMuse = "Microdatos\\victimas_map_muse.csv"

# %% [markdown]
# #### Lecturas de los datos en dataframes

# %%
data1 = pd.read_csv(accionesBelicas, sep=",")
data2 = pd.read_csv(danosBienes, sep=",")
data3 = pd.read_csv(casosDesaparicion, sep=",")
data4 = pd.read_csv(casosMapMuse, sep=",")
data5 = pd.read_csv(victimasAcciones, sep=",")
data6 = pd.read_csv(victimasDanos, sep=",")
data7 = pd.read_csv(victimasDesaparicion, sep=",")
data8 = pd.read_csv(victimasMapMuse, sep=",")

# %% [markdown]
# #### Validación de la carga de los datos y formato de carga a mongodb

# %%
data1.to_dict('records')
# Out:
# [{'IdCaso': 1,
#   'IdCasoRelacionado': 'Cr000497',
#   'DIAH': 12,
#   'MESH': 3,
#   'ANNOH': 2006,
#   'REGION': 'Atrato',
#   'DEPTO_CASO': 'Chocó',
#   'MUNINICIO_CASO': 'Bagadó',
#   'Modalidad': 'Combate y/o contacto armado',
#   'Iniciativa': 'Grupos armados organizados',
#   'TipoUnidadAtacada': 'Sin información',
#   'PRESUNTO_REPONSABLE': 'Agente del estado',
#   'DESCRIPCION_PRESUNTO_RESPONSABLE': 'Ejército nacional',
#   'PRESUNTO_REPONSABLE2': 'Guerrilla',
#   'DESCRIPCION_PRESUNTO_RESPONSABLE2': 'Farc',
#   'PRESUNTO_REPONSABLE3': nan,
#   'DESCRIPCION_PRESUNTO_RESPONSABLE3': nan,
#   'Capturas': 0.0,
#   'GrupoPertenecenLosCapturados': nan,
#   'LesionadosCiviles': 6.0,
#   'LesionadosCombatientes': 0.0,
#   'TotalMilitares': 0.0,
#   'TotalPolicias': 0.0,
#   'TotalOtrasFuerzasArmadasEstatales': 0.0,
#   'TotalAgentesEstadoSinInformacion': 0.0,
#   'TotalCombatientesFuerzasArmadasDelEstado': 0.0,
#   'TotalCombatientesDeLasGuerrillas': 0.0,
# ...

# %% [markdown]
# #### Carga de los datos al motor

# %%
db.accionesBelicas.insert_many(data1.to_dict('records'))

# %%
db.danosBienes.insert_many(data2.to_dict('records'))

# %%
db.casosDesaparicion.insert_many(data3.to_dict('records'))

# %%
db.casosMapMuse.insert_many(data4.to_dict('records'))

# %%
db.victimasAcciones.insert_many(data5.to_dict('records'))

# %%
db.victimasDanos.insert_many(data6.to_dict('records'))

# %%
db.victimasDesaparicion.insert_many(data7.to_dict('records'))

# %%
db.victimasMapMuse.insert_many(data8.to_dict('records'))
